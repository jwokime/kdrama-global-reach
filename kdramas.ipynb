# %% [markdown]
# # Which country watches the most K-drama?
#
# I will be using two datasets: 1) Netflix global ratings available to download from their [official website](https://www.netflix.com/tudum/top10/) and 2) scraped data from [MyDramaList.com](https://mydramalist.com/search?adv=titles&ty=68,77,86&co=3&st=1&so=relevance)

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import altair as alt

# %% [markdown]
# ### MyDramaList Scrape Data
#
# First, scraping. I'm pulling a list of K-drama titles from MyDramaList.com:

# %%
url = f"https://mydramalist.com/search?adv=titles&ty=68,83,86&co=3&st=3&so=top&page={page}"
html = requests.get(url)
soup = BeautifulSoup(html.text, 'html.parser')

# %%
# I'm making some functions so that it's easier to extract the info that I need from what I'm scraping.
def find_year(string):
    matches = re.findall(r'(\d{4})', string)
    year = int(matches[0]) if matches else None
    return year

def find_rank(string):
    rank = int(re.search(r'\d+', string).group())
    return rank

# %%
cards = soup.select_one(".b-primary")

# %%
# I need a list of all K-drama titles that this database has, 
# so I'm going to iterate through all the pages of the MyDramaList database to collect a title master list.

kdrama_titles=[]
page = 1

while page <= 250:
    url = f"https://mydramalist.com/search?adv=titles&ty=68,83,86&co=3&st=3&so=top&page={page}"
    html = requests.get(url)
    soup = BeautifulSoup(html.text, 'html.parser')
    page_cards = soup.select(".b-primary .title a")
    
    page_titles = list(filter(None, [t.text.strip() for t in page_cards]))
    kdrama_titles = kdrama_titles + page_titles
    
    page += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[387], line 18
#      14     kdrama_titles = kdrama_titles + page_titles
#      16     page += 1
# ---> 18 kdrama_titles.remove('Friends').remove('Suits')
#      19 print(kdrama_titles)
#
# AttributeError: 'NoneType' object has no attribute 'remove'

# %%
kdrama_titles.remove('Friends')
kdrama_titles.remove('Suits')
kdrama_titles.remove('The Empress')
kdrama_titles.remove('Lucifer')
print(kdrama_titles)
# Out:
# ['Going Seventeen 2020', 'Going Seventeen 2021', 'BTS in the Soop Season 2', 'Going Seventeen 2022', 'Break The Silence: Docu-Series', 'Going Seventeen 2019', 'Run BTS! 2022 Special Episode: Fly BTS Fly', 'Seventeen in the Soop', 'Bring The Soul: Docu-Series', 'Twinkling Watermelon', 'Going Seventeen 2023', "EXO's Ladder Season 2", 'Run BTS! 2022 Special Episode: Telepathy', 'Move to Heaven', 'Lovely Runner', 'EXO Arcade Season 1', 'Weak Hero Class 1', 'Hospital Playlist Season 2', 'Flower of Evil', 'BTS in the Soop Season 2: Behind The Scene', 'Alchemy of Souls', 'Moving', 'EXO Arcade Season 2', "Let's BTS", 'Hospital Playlist', 'NCT WORLD 2.0', 'Reply 1988', "Young Actors' Retreat", 'New Journey to the West Season 4', 'SKZ Family', 'My Mister', 'BTS Monuments: Beyond the Star', 'Nana Tour with Seventeen', "Under the Queen's Umbrella", 'Monsta X - Ray Season 2', 'New Journey to the West Season 3', 'Crash Landing on You', 'The Glory Part 2', 'Seventeen in the Soop Season 2', 'Run BTS! 2023 Special Episode: Next Top Genius', 'Mother', 'Dr. Romantic Season 3', 'Run BTS! 2023 Special Episode: Mini Field Day', 'BTS: Bon Voyage Behind Cam', 'Mr. Queen', 'Bangtan Attic', 'Prison Playbook', 'Monsta X - Ray Season 1', "Hyori's Bed And Breakfast", "It's Okay to Not Be Okay", 'My Dearest', 'Treasure Map Season 1', 'Alchemy of Souls Season 2: Light and Shadow', 'BTS: Bon Voyage 2 Behind Cam', 'Making of BT21', 'Extraordinary Attorney Woo', "EXO's Showtime", 'The Glory', 'Navillera', 'BTS: Bon Voyage 3 Behind Cam', 'BTS: Bon Voyage 4 Behind Cam', 'Vincenzo', 'ATEEZ Fever Road', 'Going Seventeen', '2021 BTS Winter Package', 'Ateez Treasure Film', 'Elite League', "Run BTS! 2022 Special Episode: 'Run BTS TV' On-air", 'My Dearest Part 2', "EXO's Ladder Season 1", 'Signal', 'iKON TV', 'The Good Bad Mother', 'Little Forest', 'Kingdom Season 2', 'New Journey to the West Season 6', 'New Journey to the West Season 5', 'Monsta X - Ray Season 3', "Jinny's Kitchen", 'Happiness', 'Mr. Sunshine', 'Show!terview with Jessi', 'Twogether', "Death's Game Part 2", 'Treasure Map Season 2', "Death's Game", "Seventeen's One Fine Day", 'Taxi Driver Season 2', 'Finding SKZ – God Edition', 'FINDING SKZ', 'BTS Dinner Party (2022)', 'Tomorrow', 'Camp ZeroBaseOne', 'Sixth Sense', 'Wanna One Go Season 2: Zero Base', 'Mouse', "GOT7's Hard Carry Season 2", 'BT21 Universe', 'Healer', 'In The Soop: Friendcation', 'Queen of Tears', 'SJ Returns Season 1', 'Goblin', 'Sixth Sense 2', 'Run BTS! Season 3', 'Twenty-Five Twenty-One', 'Stranger', 'New Journey to the West Season 7', 'ENHYPEN&Hi Season 1', 'Rookie King: Channel Bangtan', 'Taxi Driver', 'The Red Sleeve', 'Tale of the Nine-Tailed 1938', "EXO's Ladder Season 3", 'Going Seventeen Spin-off', 'Hit the Road', 'D.P.', 'BTS ARMY Corner Store', 'The Uncanny Counter', 'Mtopia', 'Weightlifting Fairy Kim Bok Joo', "GOT7's Hard Carry Season 1", '7llin’ in the DREAM', 'Kingdom', 'Busted Season 2', 'SKY Castle', 'HyeMiLeeYeChaePa', "Love for Love's Sake", 'Super TV Season 1', 'New Journey to the West Season 8', 'Salary Lupin Ateez', 'Missing: The Other Side Season 2', 'A Shop for Killers', '2 Days & 1 Night Season 3', 'Run BTS! Season 2', "EXO's Ladder Season 4", 'BTS in the Soop Season 1', 'Three Meals a Day: Doctors', 'BTS MBTI Lab', "Kang's Kitchen Season 2", 'Coffee Friends', 'Going Seventeen 2022 Special', '24/365 with BLACKPINK', 'All-Night SKZ', 'Daily Dose of Sunshine', 'Youth of May', "Kang's Kitchen Season 1", "Kang's Kitchen Season 3", 'Stray Kids: Kingdom Week', 'Hospital Playlist Goes Camping', 'Beyond Evil', 'Begins Youth', 'Dr. Romantic Season 2', 'Busted Season 3', 'Racket Boys', 'Through the Darkness', 'BTS: Bon Voyage 4', 'Nana Tour with Seventeen Uncut', 'SKZ Flix', 'Dear My Friends', 'Arthdal Chronicles Part 3: The Prelude to All Legends', 'Partners for Justice Season 2', 'Life on Mars', 'Playground', "MONSTA X's Right Now!", 'The Devil Judge', 'Moon Lovers: Scarlet Heart Ryeo', 'The Great Escape: Season 2', 'Ho ...

# %% [markdown]
# Turns out, there are a couple of K-dramas that have the same name as other popular non-Korean TV shows like "Friends," "Suits", or "Lucifer". Unfortunately, there's no way to specify in my Netflix database that I only want to see the K-drama versions of these shows, so I'm just going to remove these from the list altogether.

# %% [markdown]
# Now I'm going to scrape the years to see the trends of the numer of K-dramas and TV shows that have aired over the years.

# %%
# List of years

kdrama_years = []
page = 1

while page <= 250:
    url = f"https://mydramalist.com/search?adv=titles&ty=68,83,86&co=3&st=3&so=top&page={page}"
    html = requests.get(url)
    soup = BeautifulSoup(html.text, 'html.parser')
    page_cards = soup.select(".b-primary .text-muted")
    
    page_years = [find_year(y.text.strip()) for y in page_cards]
    kdrama_years = kdrama_years + page_years
    
    page += 1

print(kdrama_years)
# Out:
# [2020, 2021, 2021, 2022, 2020, 2019, 2022, 2021, 2019, 2023, 2023, 2019, 2022, 2021, 2024, 2018, 2022, 2021, 2020, 2021, 2022, 2023, 2021, 2021, 2020, 2020, 2015, 2022, 2017, 2021, 2018, 2023, 2024, 2022, 2017, 2017, 2019, 2023, 2023, 2023, 2018, 2023, 2023, 2016, 2020, 2019, 2017, 2017, 2017, 2020, 2023, 2020, 2022, 2017, 2017, 2022, 2013, 2022, 2021, 2018, 2019, 2021, 2020, 2017, 2021, 2019, 2023, 2022, 2023, 2018, 2016, 2018, 2023, 2019, 2020, 2018, 2018, 2018, 2023, 2021, 2018, 2020, 2020, 2024, 2021, 2023, 2016, 2023, 2020, 2019, 2022, 2022, 2023, 2020, 2017, 2021, 2018, 2019, 2014, 2022, 2024, 2017, 2016, 2021, 2019, 2022, 2017, 2019, 2020, 2013, 2021, 2023, 2022, 2018, 2020, 2021, 2021, 2020, 2020, 2016, 2016, 2021, 2019, 2021, 2019, 2018, 2023, 2024, 2018, 2020, 2021, 2022, 2024, 2013, 2017, 2023, 2020, 2021, 2022, 2019, 2019, 2022, 2020, 2021, 2023, 2021, 2017, 2019, 2021, 2021, 2021, 2024, 2020, 2021, 2021, 2022, 2019, 2024, 2023, 2016, 2019, 2019, 2018, 2021, 2016, 2021, 2016, 2019, 2021, 2017, 2023, 2019, 2021, 2022, 2018, 2015, 2022, 2017, 2017, 2018, 2020, 2017, 2023, 2015, 2020, 2015, 2021, 2022, 2019, 2018, 2022, 2022, 2018, 2016, 2018, 2021, 2021, 2018, 2020, 2018, 2016, 2020, 2024, 2019, 2021, 2020, 2018, 2020, 2017, 2014, 2020, 2019, 2023, 2017, 2018, 2022, 2003, 2021, 2023, 2023, 2017, 2019, 2021, 2015, 2018, 2016, 2019, 2020, 2020, 2017, 2017, 2010, 2022, 2017, 2023, 2017, 2019, 2021, 2022, 2020, 2019, 2020, 2018, 2023, 2017, 2016, 2017, 2014, 2018, 2017, 2023, 2021, 2017, 2021, 2022, 2016, 2018, 2018, 2024, 2022, 2018, 2017, 2021, 2023, 2017, 2016, 2020, 2021, 2020, 2018, 2019, 2020, 2018, 2020, 2022, 2023, 2016, 2024, 2020, 2015, 2022, 2017, 2018, 2017, 2021, 2018, 2018, 2022, 2021, 2017, 2013, 2022, 2013, 2017, 2012, 2015, 2017, 2021, 2022, 2020, 2018, 2019, 2016, 2019, 2022, 2017, 2023, 2020, 2022, 2017, 2022, 2017, 2020, 2020, 2017, 2020, 2013, 2024, 2019, 2018, 2022, 2023, 2023, 2022, 2016, 2021, 2020, 2018, 2021, 2017, 2013, 2021, 2018, 2021, 2022, 2023, 2016, 2024, 2017, 2022, 2017, 2019, 2022, 2020, 2009, 2019, 2016, 2023, 2016, 2014, 2022, 2014, 2016, 2010, 2020, 2015, 2014, 2022, 2023, 2019, 2017, 2020, 2019, 2021, 2013, 2019, 2020, 2017, 2019, 2019, 2024, 2008, 2021, 2018, 2022, 2021, 2012, 2013, 2022, 2019, 2007, 2023, 2019, 2020, 2017, 2023, 2021, 2021, 2015, 2021, 2020, 2023, 2021, 2019, 2011, 2020, 2015, 2021, 2020, 2013, 2013, 2019, 2022, 2011, 2024, 2023, 2020, 2019, 2021, 2021, 2020, 2023, 2021, 2021, 2020, 2016, 2014, 2017, 2018, 2017, 2017, 2023, 2020, 2018, 2018, 2020, 2020, 2014, 2020, 2020, 2020, 2015, 2022, 2019, 2016, 2021, 2012, 2015, 2019, 2021, 2022, 2020, 2020, 2019, 2019, 2012, 2018, 2017, 2023, 2021, 2021, 2021, 2014, 2020, 2021, 2023, 2023, 2022, 2017, 2017, 2021, 2019, 2019, 2022, 2021, 2017, 2019, 2021, 2012, 2021, 2021, 2020, 2023, 2017, 2019, 2020, 2014, 2018, 2023, 2022, 2024, 2021, 2020, 2015, 2022, 2015, 2017, 2019, 2020, 2016, 2017, 2020, 2019, 2017, 2019, 2019, 2020, 2018, 2020, 2022, 2014, 2023, 2022, 2017, 2019, 2020, 2020, 2015, 2020, 2020, 2021, 2023, 2016, 2020, 2019, 2024, 2016, 2015, 2016, 2017, 2019, 2020, 2021, 2022, 2006, 2021, 2019, 2016, 2017, 2022, 2019, 2020, 2018, 2019, 2018, 2021, 2022, 2018, 2021, 2020, 2013, 2020, 2022, 2018, 2019, 2020, 2019, 2020, 2021, 2024, 2020, 2013, 2013, 2020, 2013, 2022, 2021, 2012, 2023, 2019, 2021, 2018, 2018, 2020, 2019, 2011, 2020, 2019, 2023, 2023, 2022, 2019, 2019, 2013, 2015, 2021, 2015, 2022, 2019, 2007, 2011, 2022, 2014, 2019, 2019, 2022, 2014, 2018, 2021, 2022, 2022, 2022, 2018, 2016, 2013, 2019, 2016, 2019, 2017, 2018, 2021, 2014, 2023, 2016, 2022, 2023, 2018, 2011, 2008, 2017, 2017, 2023, 2022, 2023, 2023, 2023, 2016, 2021, 2023, 2007, 2017, 2019, 2017, 2023, 2005, 2011, 2021, 2016, 2024, 2015, 2024, 2018, 2022, 2021, 2018, 2014, 2010, 2018, 2018, 2019, 2019, 2014, 2023, 2023, 2019, 2023, 2012, 2023, 2015, 2016, 2015, 2019, 2019, 2019, 2015, 2018, 2017, 2018, 2014, 2016, 2016, 2018, 2021, 2017, 2021, 2018, 202 ...

# %%
kdrama_year_df = pd.DataFrame({
    'year': kdrama_years
    })
kdrama_year_df
# Out:
#       year
# 0     2020
# 1     2021
# 2     2021
# 3     2022
# 4     2020
# ...    ...
# 4807  2023
# 4808  2018
# 4809  2013
# 4810  2021
# 4811  2023
#
# [4812 rows x 1 columns]

# %%
kdramas_per_year = kdrama_year_df.groupby('year').size().reset_index(name='kdrama_count').drop([36])
kdrama_chart = alt.Chart(kdramas_per_year).mark_line().encode(
    alt.X('year:O', title='Year'),
    alt.Y('kdrama_count:Q', title='Number of K-dramas Aired in Year'),
    color=alt.value('#C54271')
)
kdrama_chart
# Out:
# alt.Chart(...)

# %%
kdrama_chart.save('kdrama_aired_per_year.html')
kdrama_chart.save('kdrama_aired_per_year.svg')
kdrama_chart.save('kdrama_aired_per_year.png')

# %% [markdown]
# ### Netflix Rankings Data
#
# Second, pulling in the Netflix country rankings data. This was just available to download as an Excel file on the Netflix official website.

# %%
df = pd.read_excel("netflix-rankings-by-country.xlsx")
shows_df = df[df['category'] != 'Films']
shows_df
# Out:
# /Users/jiwonkim/.pyenv/versions/3.11.8/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:241: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#        country_name country_iso2        week category  weekly_rank  \
# 10        Argentina           AR  2024-06-23       TV            1
# 11        Argentina           AR  2024-06-23       TV            2
# 12        Argentina           AR  2024-06-23       TV            3
# 13        Argentina           AR  2024-06-23       TV            4
# 14        Argentina           AR  2024-06-23       TV            5
# ...             ...          ...         ...      ...          ...
# 290855      Vietnam           VN  2021-07-04       TV            6
# 290856      Vietnam           VN  2021-07-04       TV            7
# 290857      Vietnam           VN  2021-07-04       TV            8
# 290858      Vietnam           VN  2021-07-04       TV            9
# 290859      Vietnam           VN  2021-07-04       TV           10
#
#                   show_title                          season_title  \
# 10                Bridgerton                  Bridgerton: Season 3
# 11            Raising Voices              Raising Voices: Season 1
# 12          Gangs of Galicia            Gangs of Galicia: Season 1
# 13                      Eric                  Eric: Limited Series
# 14                Bridgerton                  Bridgerton: Season 1
# ...                      ...                                   ...
# 290855            Reply 1988                  Reply 1988: Season 1
# 290856         Nevertheless,         Nevertheless,: Limited Series
# 290857     Too Hot to Handle           Too Hot to Handle: Season 2
# 290858    Record of Ragnarok          Record of Ragnarok: Season 1
# 290859  Crash Landing on You  Crash Landing on You: Limited Series
#
#         cumulative_weeks_in_top_10
# 10                               6
# 11                               4
# 12                               1
# 13                               4
# 14                               8
# ...                            ...
# 290855                           1
# 290856                           1
# 290857                           1
# 290858                           1
# 290859                           1
#
# [145430 rows x 8 columns]

# %% [markdown]
# Next, I'm going to filter for all the rows where the show_title is in the list of K-drama show titles. If there's a match, that means that  particular K-drama was in the country's top 10 rankings that week.

# %%
kdrama_df = shows_df[shows_df['show_title'].isin(kdrama_titles)]
kdrama_df
# Out:
#        country_name country_iso2        week category  weekly_rank  \
# 34        Argentina           AR  2024-06-16       TV            5
# 98        Argentina           AR  2024-05-26       TV            9
# 139       Argentina           AR  2024-05-12       TV           10
# 179       Argentina           AR  2024-04-28       TV           10
# 199       Argentina           AR  2024-04-21       TV           10
# ...             ...          ...         ...      ...          ...
# 290852      Vietnam           VN  2021-07-04       TV            3
# 290854      Vietnam           VN  2021-07-04       TV            5
# 290855      Vietnam           VN  2021-07-04       TV            6
# 290856      Vietnam           VN  2021-07-04       TV            7
# 290859      Vietnam           VN  2021-07-04       TV           10
#
#                   show_title                          season_title  \
# 34                 Hierarchy             Hierarchy: Limited Series
# 98                The 8 Show            The 8 Show: Limited Series
# 139           Queen of Tears        Queen of Tears: Limited Series
# 179           Queen of Tears        Queen of Tears: Limited Series
# 199       Parasyte: The Grey    Parasyte: The Grey: Limited Series
# ...                      ...                                   ...
# 290852              Vincenzo                    Vincenzo: Season 1
# 290854     Hospital Playlist           Hospital Playlist: Season 2
# 290855            Reply 1988                  Reply 1988: Season 1
# 290856         Nevertheless,         Nevertheless,: Limited Series
# 290859  Crash Landing on You  Crash Landing on You: Limited Series
#
#         cumulative_weeks_in_top_10
# 34                               1
# 98                               1
# 139                              3
# 179                              2
# 199                              3
# ...                            ...
# 290852                           1
# 290854                           1
# 290855                           1
# 290856                           1
# 290859                           1
#
# [17722 rows x 8 columns]

# %% [markdown]
# Now to find the true Koreaboos. I'm going to simply group by the countries and count how many weeks a K-drama made the country's top 10 list.

# %%
koreaboo_df = kdrama_df.groupby('country_name').size().reset_index(name='count').sort_values('count', ascending=False).reset_index(drop=True).set_axis(['DW_NAME', 'VALUE'], axis=1)
print(koreaboo_df)
# Out:
#         DW_NAME  VALUE
# 0   South Korea   1000
# 1     Indonesia    868
# 2       Vietnam    856
# 3      Malaysia    769
# 4      Thailand    734
# ..          ...    ...
# 89      Iceland     30
# 90        Malta     29
# 91       Russia     26
# 92      Ireland     23
# 93      Ukraine     22
#
# [94 rows x 2 columns]

# %%
# Exporting so that I can use Datawrapper to put it onto a map
koreaboo_df.to_csv('koreaboos.csv')

# %%
merged_df = kdrama_df.merge(koreaboos_df, left_on='country_name', right_on='DW_NAME')
merged_df.fillna(0)
merged_df.to_csv('merged_koreaboos.csv')

# %% [markdown]
# Now I want to know which shows were the most popular in each country.

# %%
# Group by country and show title, and find the show that has the max cumulative weeks in top 10
pop_show = kdrama_df.groupby(['country_name', 'show_title'])['cumulative_weeks_in_top_10'].max().reset_index()
pop_show_by_country = pop_show.sort_values('cumulative_weeks_in_top_10', ascending=False).groupby('country_name').first().reset_index()
pop_show_by_country
# Out:
#       country_name                  show_title  cumulative_weeks_in_top_10
# 0        Argentina                  Squid Game                          11
# 1        Australia                  Squid Game                          11
# 2          Austria                  Squid Game                          12
# 3          Bahamas                  Squid Game                           9
# 4          Bahrain                  Squid Game                          16
# ..             ...                         ...                         ...
# 89  United Kingdom                  Squid Game                          10
# 90   United States                  Squid Game                          11
# 91         Uruguay                  Squid Game                           9
# 92       Venezuela  Extraordinary Attorney Woo                          11
# 93         Vietnam                  Reply 1988                          39
#
# [94 rows x 3 columns]

# %% [markdown]
# Which shows were the most popular overall?

# %%
# This is looking at how many countries had a particular K-drama for the most cumulative weeks
pop_show_by_country.groupby('show_title').size().reset_index(name='count').sort_values('count', ascending=False)
# Out:
#                     show_title  count
# 9                   Squid Game     65
# 12                 True Beauty      6
# 0             Alchemy of Souls      5
# 4   Extraordinary Attorney Woo      5
# 10                   The Glory      3
# 5            Hospital Playlist      2
# 1            Boys Over Flowers      1
# 2            Business Proposal      1
# 3         Crash Landing on You      1
# 6                     My Demon      1
# 7               Queen of Tears      1
# 8                   Reply 1988      1
# 11                 The Promise      1
# 13                    Vincenzo      1

# %%
# This is more simply looking at how many times a particular K-drama shows up in the database
kdrama_df.groupby('show_title').size().reset_index(name='popularity score').sort_values('popularity score', ascending=False).head(10)
# Out:
#                      show_title  popularity score
# 172                  Squid Game              1233
# 10             Alchemy of Souls               623
# 11           All of Us Are Dead               622
# 192                   The Glory               592
# 142               Physical: 100               535
# 58   Extraordinary Attorney Woo               518
# 114                    My Demon               502
# 219                 True Beauty               468
# 32            Business Proposal               458
# 88                King the Land               451

# %%
pop_show = kdrama_df.groupby(['country_name', 'show_title'])['cumulative_weeks_in_top_10'].max().reset_index()

# %%
#Or maybe what I want to say is "this show reached top 10 in this many countries, keeping its spot in the top 10 for an average of __ weeks."
popular_kdramas = pop_show.groupby('show_title').agg(
    num_countries=('country_name', 'count'),
    mean_weeks_in_top_10=('cumulative_weeks_in_top_10', 'mean')
).sort_values('num_countries', ascending=False).reset_index()
top_kdramas=popular_kdramas.head(5)
top_kdramas
# Out:
#            show_title  num_countries  mean_weeks_in_top_10
# 0          Squid Game             94             13.117021
# 1  All of Us Are Dead             94              6.617021
# 2           Hellbound             93              2.333333
# 3           The Glory             91              6.505495
# 4       Physical: 100             91              3.868132

# %%
top_kdramas.to_csv('top_kdramas.csv')

# %%
# Trying out a scatterplot to see what it looks like
alt.Chart(popular_kdramas).mark_circle(size=60).encode(
    alt.X('num_countries:O', title='Number of Countries with Show in Top 10'),
    alt.Y('mean_weeks_in_top_10:Q', title='Mean Weeks in Top 10'),
    tooltip=['show_title']).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# Are K-dramas getting more or less popular with each passing year?

# %%
kdrama_df['week'] = pd.to_datetime(kdrama_df['week'])
# Out:
# /var/folders/g8/dvbwkwcx05b4v8g_m29p0w8w0000gn/T/ipykernel_24941/3314108104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kdrama_df['week'] = pd.to_datetime(kdrama_df['week'])

# %%
kdrama_df['year'] = kdrama_df['week'].dt.year
# Out:
# /var/folders/g8/dvbwkwcx05b4v8g_m29p0w8w0000gn/T/ipykernel_24941/3495079362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kdrama_df['year'] = kdrama_df['week'].dt.year

# %%
kdrama_df
# Out:
#        country_name country_iso2       week category  weekly_rank  \
# 34        Argentina           AR 2024-06-16       TV            5
# 98        Argentina           AR 2024-05-26       TV            9
# 139       Argentina           AR 2024-05-12       TV           10
# 179       Argentina           AR 2024-04-28       TV           10
# 199       Argentina           AR 2024-04-21       TV           10
# ...             ...          ...        ...      ...          ...
# 290852      Vietnam           VN 2021-07-04       TV            3
# 290854      Vietnam           VN 2021-07-04       TV            5
# 290855      Vietnam           VN 2021-07-04       TV            6
# 290856      Vietnam           VN 2021-07-04       TV            7
# 290859      Vietnam           VN 2021-07-04       TV           10
#
#                   show_title                          season_title  \
# 34                 Hierarchy             Hierarchy: Limited Series
# 98                The 8 Show            The 8 Show: Limited Series
# 139           Queen of Tears        Queen of Tears: Limited Series
# 179           Queen of Tears        Queen of Tears: Limited Series
# 199       Parasyte: The Grey    Parasyte: The Grey: Limited Series
# ...                      ...                                   ...
# 290852              Vincenzo                    Vincenzo: Season 1
# 290854     Hospital Playlist           Hospital Playlist: Season 2
# 290855            Reply 1988                  Reply 1988: Season 1
# 290856         Nevertheless,         Nevertheless,: Limited Series
# 290859  Crash Landing on You  Crash Landing on You: Limited Series
#
#         cumulative_weeks_in_top_10  year
# 34                               1  2024
# 98                               1  2024
# 139                              3  2024
# 179                              2  2024
# 199                              3  2024
# ...                            ...   ...
# 290852                           1  2021
# 290854                           1  2021
# 290855                           1  2021
# 290856                           1  2021
# 290859                           1  2021
#
# [18600 rows x 9 columns]

# %%
# On average, how often does a K-drama make the Netflix top 10 in a year in any given country?

by_country = kdrama_df.groupby(['year', 'country_name']).size().reset_index(name='kdrama_count')
by_year = by_country.groupby('year').mean('kdrama_count').reset_index()
by_year
# Out:
#    year  kdrama_count
# 0  2021     42.563830
# 1  2022     62.297872
# 2  2023     67.161290
# 3  2024     26.849462

# %%
by_year['kdrama_percent'] = by_year['kdrama_count']/520
# Dropping 2024 because the year isn't over yet and doesn't show the full picture
by_year = by_year.drop([3])

# %%
by_year['year'] = by_year['year'].astype(int)
by_year['kdrama_percent'] = by_year['kdrama_percent'].astype(float)

# %%
alt.Chart(by_year).mark_line().encode(
    alt.X('year:O', title='Year'),
    alt.Y('kdrama_percent:Q', title='Percent of year K-drama is in top 10') 
).properties(width=500)
# Out:
# alt.Chart(...)
